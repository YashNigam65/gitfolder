# %% [markdown]
# <a href="https://colab.research.google.com/github/YashNigam65/gitfolder/blob/master/speech_to_text_open_source_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install torch
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-koxqhlr4
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-koxqhlr4
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=3cedcb1abf8b71cfe02416c8bf834029475a185040d9c7da92ca9fb5ccc8e709
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lbtujs62/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# ...

# %%
import whisper

# Load the model (tiny, base, small, medium, or large)
model = whisper.load_model("base")  # Use "tiny" for speed or "large" for accuracy

# Transcribe an audio file
result = model.transcribe("/content/sample_data/output.wav")

# Print the result
print("📝 Transcription:")
print(result["text"])
# Out:
# 📝 Transcription:
#  Hello, this is a demonstration of open source text to speech using coquettes.

# %% [markdown]
# Let's try running the installation cell again to ensure the correct versions of the libraries are loaded in this environment.

# %%
# Based on the output you provided, the phrase "using coquettes"
# appears to be a transcription artifact. It's likely a misinterpretation
# by the speech-to-text model of the word "Coqui," which is an open-source
# project related to speech technologies. Coqui provides tools and models
# for tasks like text-to-speech and speech-to-text. So, in this context,
# "Coqui" is the name of the open-source project being used for the
# speech-to-text demonstration, and "coquettes" was a mis-transcription of that name.
